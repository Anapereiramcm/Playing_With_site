# %% [markdown]
# <a href="https://colab.research.google.com/github/Anapereiramcm/Playing_With_site/blob/main/RestaurantePobre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Entrada

a = str (input("Seja bem-vindo(a) ao nosso restaurante! Digite o seu nome:  "))
print("")
print(f"Seja bem vindo(a), {a}! ")
print ("Aqui está o nosso menu:  ")
print("")
print("-----------------")
print("| Picanha: 1    |")
print("| Lasanha: 2    |")
print("| Feijoada: 3   |")
print("| Pizza: 4      |")
print("| Hambúrguer: 5 |")
print("-----------------")
print("")
b = int(input("Digite o prato que deseja:  "))

if b == 1:
  print("")
  print(f"a picanha sairá por R$45,00")
  print("")
  print("----PAGAMENTO-----")
  print("| Crédito: 100   |")
  print("| Débito: 200    |")
  print("| Dinheiro: 300  |")
  print("------------------")
  paga = int (input("Por favor, selecione o meio de pagamento:  "))
  if paga == 100:
    print("")
    print("Muito obrigado pelo pagamento em crédito, aqui está a chave pix: 1234.")
  elif paga == 200:
    print("")
    print("Muito obrigado pelo pagamento em débito, aqui está a chave pix: 1234")
  elif paga == 300:
    print("")
    print("Muito obrigado pelo pagamento em dinheiro. Venha até a loja física para pagar.")


elif b == 2:
  print("A lasanha sairá por R$20,00")
  print("")
  print("----PAGAMENTO-----")
  print("| Crédito: 100   |")
  print("| Débito: 200    |")
  print("| Dinheiro: 300  |")
  print("------------------")
  paga = int (input("Por favor, selecione o meio de pagamento:  "))
  if paga == 100:
    print("")
    print("Muito obrigado pelo pagamento em crédito, aqui está a chave pix: 1234.")
  elif paga == 200:
    print("")
    print("Muito obrigado pelo pagamento em débito, aqui está a chave pix: 1234")
  elif paga == 300:
    print("")
    print("Muito obrigado pelo pagamento em dinheiro. Venha até a loja física para pagar.")

elif b == 3:
  print("A feijoada sairá por R$15,00")
  print("")
  print("----PAGAMENTO-----")
  print("| Crédito: 100   |")
  print("| Débito: 200    |")
  print("| Dinheiro: 300  |")
  print("------------------")
  paga = int (input("Por favor, selecione o meio de pagamento:  "))
  if paga == 100:
    print("")
    print("Muito obrigado pelo pagamento em crédito, aqui está a chave pix: 1234.")
  elif paga == 200:
    print("")
    print("Muito obrigado pelo pagamento em débito, aqui está a chave pix: 1234")
  elif paga == 300:
    print("")
    print("Muito obrigado pelo pagamento em dinheiro. Venha até a loja física para pagar.")

elif b == 4:
  print("A pizza sairá por R$30,00")
  print("")
  print("----PAGAMENTO-----")
  print("| Crédito: 100   |")
  print("| Débito: 200    |")
  print("| Dinheiro: 300  |")
  print("------------------")
  paga = int (input("Por favor, selecione o meio de pagamento:  "))
  if paga == 100:
    print("")
    print("Muito obrigado pelo pagamento em crédito, aqui está a chave pix: 1234.")
  elif paga == 200:
    print("")
    print("Muito obrigado pelo pagamento em débito, aqui está a chave pix: 1234")
  elif paga == 300:
    print("")
    print("Muito obrigado pelo pagamento em dinheiro. Venha até a loja física para pagar.")

elif b == 5:
  print("O Hambúrguer sairá por R$10,00")
  print("")
  print("----PAGAMENTO-----")
  print("| Crédito: 100   |")
  print("| Débito: 200    |")
  print("| Dinheiro: 300  |")
  print("------------------")
  paga = int (input("Por favor, selecione o meio de pagamento:  "))
  if paga == 100:
    print("")
    print("Muito obrigado pelo pagamento em crédito, aqui está a chave pix: 1234.")
  elif paga == 200:
    print("")
    print("Muito obrigado pelo pagamento em débito, aqui está a chave pix: 1234")
  elif paga == 300:
    print("")
    print("Muito obrigado pelo pagamento em dinheiro. Venha até a loja física para pagar.")

else:
  print("Opção inválida.")
# Out:
# Seja bem-vindo(a) ao nosso restaurante! Digite o seu nome:  Ana
#
# Seja bem vindo(a), Ana!
# Aqui está o nosso menu:
#
# -----------------
# | Picanha: 1    |
# | Lasanha: 2    |
# | Feijoada: 3   |
# | Pizza: 4      |
# | Hambúrguer: 5 |
# -----------------
#
# Digite o prato que deseja:  5
# O Hambúrguer sairá por R$10,00
#
# ----PAGAMENTO-----
# | Crédito: 100   |
# | Débito: 200    |
# | Dinheiro: 300  |
# ------------------
# Por favor, selecione o meio de pagamento:  200
#
# Muito obrigado pelo pagamento em débito, aqui está a chave pix: 1234
